# %%
import torch

# %%
pred_tree = torch.load("../train/pred.pt")
pred_traversal = torch.load("../train/pred-traversal.pt")
print(pred_tree[3:-3])
# Out:
# tensor([[[ 0.1312,  0.0871, -0.2414,  0.1127,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [ 0.1090,  0.1233, -0.2217,  0.0625,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [-0.0457,  0.0118, -0.2824,  0.1827,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [ 0.0925,  0.2054, -0.3040, -0.0384,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [-0.0762,  0.0858, -0.2146,  0.1433,  0.1147,  0.1266, -0.2099,
#            0.0799]],
#
#         [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000]],
#
# ...

# %%
print(pred_traversal[3:-3])
# Out:
# tensor([[[ 0.1312,  0.0871, -0.2414,  0.1127,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [ 0.1090,  0.1233, -0.2217,  0.0625,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [-0.0490,  0.0084, -0.2802,  0.1797,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [ 0.0908,  0.2054, -0.3040, -0.0384,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [-0.0790,  0.0860, -0.2114,  0.1411,  0.1147,  0.1266, -0.2099,
#            0.0799],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000]],
#
#         [[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
# ...
